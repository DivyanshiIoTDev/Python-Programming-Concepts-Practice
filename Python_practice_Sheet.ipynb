# %%
"""
Question 1. Given two integer variables a and b, and a boolean variable flag. The task is to
check the status and return accordingly.
Return True for the following cases:
Either a or b (not both) is non-negative and the flag is false.
Both a and b are negative and the flag is true.
Otherwise, return False.
"""
def check_case(a,b,flag):
 if (a<=0 and b>=0) or (a>=0 and b<=0) and not flag:
    return True
 elif(a<=0 and b<=0)and flag:
    return True
 else:
    return False
a=int(input("enter a"))
b=int(input("enter b"))
flag=bool(input("enter flag in boolean"))
value=check_case(a,b,flag)
print(value)
# Out:
# enter a-1
# enter b4
# enter flag in boolean1
# True

# %% [markdown]
# #Pseudocode
#     START
#     PROMPT USER TO ENTER a,b
#     READ a,b
#     READ flag
#     DEFINE FUNCTION CHECK_CASE(a,b,flag):
#     IF (a<=0 and b>=0) OR (a>=0 and b<=0) AND NOT flag THEN
#     RETURN True
#     ELSE IF (a<=0 and b>=0)AND flag THEN
#     RETURN True
#     ELSE
#     RETURN False
#     SET Value=RETURNED value from check_case function
#     DISPLAY vALUE
#
#
# #Flowchart
# ![Screenshot_5-2-2025_224811_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
"""
Question 2 Given a positive integer x. Your task is to check, if it is even or odd (Any
number that gives zero as remainder when divided by 2 is an even number).Your task is to complete the function checkOddEven(), which returns True (In python,
True starts with caps T) if the number is even, else return False (In Python, False starts with
caps F).
"""
def checkOddEven():
    x=int(input("Enter value of x"))
    try:
      if (x%2==0):
         return True
      else:
         return False
    except TypeError:
        print("enter valid integer")

value=checkOddEven()
if value==True:
    print("Even number")
else:
    print("Odd Number")
# Out:
# Enter value of x4
# Even number

# %% [markdown]
# #PSEUDOCODE
#     START
#     CALL FUNCTION checkOddEven(x)
#     READ x
#     TRY
#     IF x mod 2==0 THEN
#     RETURN True
#     ELSE
#     RETURN FALSE
#     EXCEPT TypeError
#     DISPLAY "Enter valid integer"
#     SET Value=RETURNED Value from function checkOddEven()
#     IF Value==True THEN
#     DISPLAY "Even Number"
#     ELSE
#     DISPLAY "Odd Number"
# #Flowchart
# ![Screenshot_5-2-2025_235225_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
"""
Question 3 You are given a string str, you need to return True if the words "cat" and "hat"
appear same number of times in str, otherwise return False.
"""
def count_fn(x):

    a=x.count("cat")
    b=x.count("hat")
    if a==b:
        return True
    else:
        return False
x=input("Enter the string")
if bool(count_fn(x))==True:
    print("They are equally repeated")
else:
    print("They are not equally repeated")
# Out:
# Enter the stringcathatcathat
# They are equally repeated

# %% [markdown]
# #PSEUDOCODE
#     START
#     READ a,b
#     CALL FUNCTION count_fn(x)
#     SET a=Count of string "cat"
#     SET b=Count of string "hat"
#     IF a==b THEN
#     RETURN True
#     ELSE
#     RETURN False
#     IF RETURNED Value==True
#     DISPLAY "They are equally repeated"
#     ELSE
#     DISPLAY "They are not equally repeated"
#     END
#
# #Flowchart
# ![Screenshot_5-2-2025_231057_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
"""
Question 4 You are given a number N, you need to print its multiplication table.
"""
x=int(input("ENTER THE NUMBER="))
for i in range (1,11):
    print(f"{x}*{i}={x*i}")
    print(f"")

# %% [markdown]
# #Pseudocode
#     START
#     READ INT x
#     FOR i in range 1 TO 10
#     DISPLAY x*i=result
#     END
# #Flowchart
# ![Screenshot_5-2-2025_231621_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
"""
Question 5. Given a number x, the task is to print the numbers from x to 0 in decreasing
order in a single line.
"""
x=int(input("Enter the value of x"))
for i in range(x,0,-1):
  print(i)

# %% [markdown]
# #Pseudocode
#     START
#     READ x
#     FOR i in RANGE(x,0)
#     i=i-1
#     DISPLAY i
# #Flowchart
# ![Screenshot_5-2-2025_231621_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
"""
Question 6. Given a positive integer x, the task is to print the numbers from 1 to
x in the order as  (in increasing order).
"""
x=int(input("Enter the number"))
for i in range(0,x+1):
    print(f"OUTPUT{i**2",end=", ")

# %% [markdown]
# #Pseudocode
#     START
#     READ int x
#     FOR i in range 1 TO x
#     DISPLAY i**2
# #Flowchart
# ![Screenshot_5-2-2025_232755_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
"""
Question 7 You are given a number n. The number n can be negative or positive. If
n is negative, print numbers from n to 0 by adding 1 to n in the neg function. If
positive, print numbers from n-1 to 0 by subtracting 1 from n in the pos function.
"""
def neg():
    for i in range(0,n+1):
        print(i)
def pos():
    for i in range(n-1,-1,-1):
        print(i)
n=int(input("Enter the number")
if n>=0:
    pos()
else:
    neg()

# %% [markdown]
# #Pseudocode
#     START
#     READ INT n
#     IF n>=0 THEN
#       CALL FUNCTION pos()
#       FOR i in RANGE 1 TO n
#          DISPLAY i
#          i=i+1
#     ELSE
#        CALL FUNCTION neg()
#        FOR i in RANGE n-1 to 0
#          PRINT i
#          i=i-1
#     END
#
# #Flowchart
#  ![Screenshot_5-2-2025_233926_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#FINDING FACTORIAL
def factorial_fn(n):
  if n==0 or n==1:
      return 1
  else:
      n=n*factorial_fn(n-1)
      return n


factorial=int(input("Enter a number"))
print(factorial_fn(factorial))

# %% [markdown]
# #Pseudocode
#     Define Function factorial_fn(n):
#     If n is 0 or n is 1:
#     Return 1
#     Else:
#     n = n * FACTORIAL_FN(n - 1)
#     Return n
#     START
#     Prompt user to "Enter a number"
#     Read factorial
#     Store user input as 'factorial'
#     Call FACTORIAL_FN(factorial)
#     print factorial
#     END
# #flowchart
# ![Screenshot_5-2-2025_16455_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#To find simple interest and compound interest
def simple_interest(principal,rate,time):
    return (principal*rate*time)/100
def compound_interest(principal,rate,time):
    return principal * (1 + rate / 100) ** time - principal
principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate of interest (in %): "))
time = float(input("Enter the time period (in years): "))

print(f"Simple interest is{simple_interest(principal,rate,time)}")
print(f"Compound interest is{compound_interest(principal,rate,time)}")

# %% [markdown]
#     START
#     Define function simple_interest(principal,rate,time):
#        RETURN (principal*rate*time)/100<br>
#     Define function compound_interest(principal,rate,time):
#        RETURN principal * (1 + rate / 100) ** time - principal
#     prompt user to enter principal
#     prompt user to enter rate
#     prompt user to enter time
#     Call function simple_interest(principal,rate,time) and display
#     Call function compound_interest(principal,rate,time) and display
#     END

# %%
#PRINT ALL PRIME NUMBERS IN AN INTERVAL
def isprime_fn(n):
    for i in range(1,(n//2)+1):
        if n%i!=0:
            return 1
        else:
            return 0
x=int(input("Enter upper limit"))
y=int(input("Enter lower limit"))
for n in range(y,x+1):
    isprime_fn(n)
    if isprime_fn(n)==1:
        print(n)

# %% [markdown]
#  Pseudocode
#
#     START
#     FUNCTION isprime_fn(n):
#         FOR i FROM 1 TO (n//2) + 1:
#             IF n%i != 0 THEN
#                 RETURN 1  # Number is prime
#             ELSE
#                 RETURN 0  # Number is not prime
#
#
#     DISPLAY "Enter upper limit:"
#     READ x
#     DISPLAY "Enter lower limit:"
#     READ y
#     FOR n from y TO x:
#         CALL isprime_fn(n)
#       IF isprime_fn(n) == 1 then
#             DISPLAY n
#
#     END
# Flowchart
# ![Screenshot_5-2-2025_17912_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#To check if a number is prime
def isprime_fn(n):
    for i in range(2,(n//2)+1):
        if n%i==0:
            return 0
        else:
            return 1
n=int(input("Enter the number"))
if isprime_fn(n)==1:
  print("it is prime")
else:
  print("It is not prime")
# Out:
# Enter the number5
# it is prime

# %% [markdown]
# #Pseudocode
#     START
#     Define function isprime_fn(n):
#         FOR i from 2 to (n // 2) + 1:
#             IF n % i == 0 THEN
#                 RETURN 0
#         RETURN 1
#     PROMPT the user to "Enter a number"
#     READ n
#     IF isprime_fn(n) == 1 Then
#         DISPLAY "It is prime"
#     ELSE
#         DISPLAY "It is not prime"
#
#     END
# #Flowchart
# ![Screenshot_5-2-2025_172126_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#To check for armstrong and perfect number
def is_armstrong(num):
    num_str = str(num)
    num_digits = len(num_str)
    sum_of_digits = sum(int(digit) ** num_digits for digit in num_str)

    if sum_of_digits == num:
        return True
    else:
        return False
def is_perfect_number(num):
    sum_of_divisors = 0
    for i in range(1, num):
        if num % i == 0:
            sum_of_divisors += i
    if sum_of_divisors == num:
        return True
    else:
        return False

number = int(input("Enter a number to check if it's an Armstrong number: "))
if is_armstrong(number):
    print(f"{number} is an Armstrong number.")
else:
    print(f"{number} is not an Armstrong number.")
if is_perfect_number(number):
    print(f"{number} is a Perfect number.")
else:
    print(f"{number} is not a Perfect number.")

# %% [markdown]
# #PSEUDOCODE
#     Function is_armstrong(num):
#     Convert num to a string (num_str)
#     set NUM_DIGITS= length of the string (num_digits)
#     Initialize sum_of_digits to 0
#     For each digit in num_str:
#         Convert the digit to an integer
#         Raise the digit to the power of num_digits
#         Add the result to sum_of_digits
#     If sum_of_digits equals num:
#         Return True
#     Else:
#         Return False
#
#     Function is_perfect_number(num):
#     Initialize sum_of_divisors to 0
#     For i from 1 to num-1:
#         If num is divisible by i (num % i == 0):
#             Add i to sum_of_divisors
#     If sum_of_divisors equals num:
#         Return True (It's a Perfect number)
#     Else:
#         Return False (It's not a Perfect number)
#
#     Start
#     Input a number (num)
#     Call the is_armstrong function with num
#     If the result is True:
#         Print "{num} is an Armstrong number"
#     Else:
#         Print "{num} is not an Armstrong number"
#
#     Call the is_perfect_number function with num
#     If the result is True:
#         Print "{num} is a Perfect number"
#     Else:
#         Print "{num} is not a Perfect number"
#     End
# #FLOWCHART
# ![Screenshot_5-2-2025_204039_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#fibonacci number printing in a range
def if_fibonacci(n):
    i=0
    b=1
    print(i)
    print(b)
    for m in range(1,n+1):
        i=i+b
        b=i
        print(i)
n=int(input("Enter a maximum range"))
if_fibonacci(n)

# %% [markdown]
# #Pseudocode
#     START
#
#     FUNCTION if_fibonacci(n):
#         SET i = 0
#         SET b = 1
#
#         PRINT i
#         PRINT b
#
#         FOR m from 1 to n-1:
#             SET i = i + b  # Update i to the next Fibonacci number (i + b)
#             SET b = i  # Set b to the previous i (moving to the next number in the sequence)
#             PRINT i  # Print the new Fibonacci number
#     DISPLAY "Enter a maximum range:"
#     READ n
#     CALL if_fibonacci(n)
#     END
#
# #FLOWCHART
#   ![Screenshot_5-2-2025_173434_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
# Function to check if a number is a Fibonacci number
import maths
def is_perfectsquare(a):
    square_root = int(math.sqrt(a))
    if square_root * square_root == a:
      return True
    else:
      return False
def is_fibonacci(n):
    return (is_perfectsquare(5 * n * n + 4) or is_perfectsquare(5 * n * n - 4)

n = int(input("Enter a number to check if it is a Fibonacci number: "))
if is_fibonacci(n):
    print(f"{n} is a Fibonacci number.")
else:
    print(f"{n} is not a Fibonacci number.")

# %% [markdown]
#  #Pseudocode
#     START
#
#     DEFINE FUNCTION is_perfectsquare(x):
#         SET square_root = sqrt(x)
#         IF square_root * square_root == x then
#         Return True
#         ELSE
#         Return False
#
#     DEFINE FUNCTION is_fibonacci(n):
#
#         IF is_perfectsquare(5 * n^2 + 4) or is_perfectsquare(5 * n^2 - 4) Then
#         Return True
#         ELSE
#         Return False
#     DISPLAY "Enter a number to check if it is a Fibonacci number:"
#     READ n
#     IF is_fibonacci(n) == True THEN
#     DISPLAY "It is a Fibonacci number."
#     ELSE
#     DISPLAY "It is not a Fibonacci number."
#
#     END
# #Flowchart
# ![Screenshot_5-2-2025_17499_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#reversing a string
s="Hello World"
c=" ".join(s[::-1])
print(c)
# Out:
# d l r o W   o l l e H

# %% [markdown]
#    #Pseudocode
#
#     START
#     SET s="Hello World"
#     SET c=Join the reversed string
#     PRINT c
#     END
#
# #Flowchart
# ![Screenshot_5-2-2025_17559_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#To check if a number is palindrome
n=input("Enter a string to check for palindrome")
if n==n[::-1]:
  print("It is palindrome")
else:
  print("It is not palindrome")

# %% [markdown]
# #Pseudocode
#     START
#     PROMPT user to "Enter a string to check for palindrome"
#     READ n
#     IF n IS EQUAL TO REVERSE OF n THEN
#     PRINT "It is palindrome"
#     ELSE
#     PRINT "It is not palindrome"
#     END
#
# #Flowchart
# ![Screenshot_5-2-2025_18142_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#To remove ith charachter from a string
s=list(input("Enter a string"))
i=int(input("position of charachter to remove"))
if i<=(len(s)-1):
  d=s.pop(i)
else:
  print("Enter a valid position")
print(f"UPDATED STRING{''.join(s)}")

# %% [markdown]
# #pseudocode
#     START
#     PROMPT USER TO "Enter a string"
#     READ s
#     PROMPT USER TO "position of charachter to remove"
#     READ i
#     IF i<LENGTH OF STRING
#       SET d=Updated list with removed ith charachter
#     ELSE
#      DISPLAY "Enter a valid position"
#     DISPLAY Updated string
# #FLOWCHART
# ![Screenshot_5-2-2025_202059_app.diagrams.net.jpeg](data:image/jpeg;base64,...)

# %%
#Remove all repeated charachters from the string
s = list(input("Enter a string: "))
b=len(s)
for j in range(0,b):
    a=s[j]
   for i in range(b-1,j,-1):
       if s[i] == a:
          s.pop(i)
          b=len(s)

print(f"{''.join(s)}")

# %% [markdown]
# #PSEUDOCODE
#     Start
#     Display "Enter a string"
#     Read s
#     Set b to the length of s
#     For j from 0 to b-1:
#         a = s[j]
#     For i from b-1 down to j+1:
#         If s[i] is equal to a:
#             Remove character at index i from s
#             Update b to the new length of s
#     Display the final string
#     End
# #FLOWCHART

# %%
#Check if there is a URL in string
def contains_url(s):
    words = string.split()
    for word in words:
        if word.startswith("http://") or word.startswith("https://"):
            return True

    return False

s= input("Enter a string: ")
if contains_url(string):
    print("URL found")
else:
    print("No URL found")

# %% [markdown]
# #Pseudocode
#
#
#     START
#     PROMPT USER TO "Enter a string"
#     READ s
#     DEFINE Function contains_url(s):
#     FOR each word in the list of words:
#         If the word starts with "http://" OR the word starts with "https://" TTHEN
#             RETURN True
#     RETURN False
#     IF the result is True THEN
#         Print "URL found"
#     ELSE
#         Print "No URL found"
#     END
#
# #Flowchart
# ![Screenshot_5-2-2025_201429_app.diagrams.net.jpeg](data:image/jpeg;base64,...)
